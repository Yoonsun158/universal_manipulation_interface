# %%
import numpy as np

duration = 10.0
sample_dt = 1 / 100
k = int(duration / sample_dt)
sample_t = np.linspace(0, duration, k)
value = np.sin(sample_t * duration / 1.5) * 0.5 + 0.5
width = value * 80
# print(sample_t)
# print(value)
print(width)
# Out:
# [4.00000000e+01 4.26673552e+01 4.53228361e+01 4.79546215e+01
#  5.05509952e+01 5.31003992e+01 5.55914842e+01 5.80131606e+01
#  6.03546480e+01 6.26055227e+01 6.47557646e+01 6.67958013e+01
#  6.87165514e+01 7.05094641e+01 7.21665580e+01 7.36804563e+01
#  7.50444194e+01 7.62523755e+01 7.72989471e+01 7.81794752e+01
#  7.88900400e+01 7.94274782e+01 7.97893973e+01 7.99741862e+01
#  7.99810222e+01 7.98098749e+01 7.94615063e+01 7.89374671e+01
#  7.82400902e+01 7.73724801e+01 7.63384991e+01 7.51427503e+01
#  7.37905567e+01 7.22879378e+01 7.06415830e+01 6.88588211e+01
#  6.69475887e+01 6.49163938e+01 6.27742787e+01 6.05307795e+01
#  5.81958836e+01 5.57799851e+01 5.32938390e+01 5.07485127e+01
#  4.81553374e+01 4.55258570e+01 4.28717772e+01 4.02049131e+01
#  3.75371368e+01 3.48803244e+01 3.22463033e+01 2.96467992e+01
#  2.70933844e+01 2.45974259e+01 2.21700350e+01 1.98220176e+01
#  1.75638265e+01 1.54055143e+01 1.33566892e+01 1.14264720e+01
# ...
